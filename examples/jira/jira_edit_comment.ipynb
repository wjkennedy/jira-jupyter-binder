# %%
# coding=utf-8
from atlassian import Jira

# %% [markdown]
#  How to edit comment
# <br>
# jira = Jira(url="https://jira.example.com/", username="gonchik.tsymzhitov", password="admin")<br>
# jira.issue_edit_comment("TST-11098", 10700, "edited test rest api request")
